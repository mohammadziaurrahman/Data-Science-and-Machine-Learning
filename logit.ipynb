# %%
import pandas as pd

# %%
df = pd.read_csv("weight-height.csv").sample(100)

# %%
print(df.shape)
print(df.head())
# Out:
# (100, 3)
#       Gender     Height      Weight
# 4175    Male  67.133444  175.152373
# 5396  Female  64.328491  135.819094
# 1572    Male  69.117657  197.491802
# 6766  Female  68.186814  159.033590
# 5843  Female  67.711232  145.408446

# %%
df["Gender"] = df["Gender"].replace(["Male","Female"],[0,1])
# Out:
# C:\Users\Sajib Saha\AppData\Local\Temp\ipykernel_12788\1521775124.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Gender"] = df["Gender"].replace(["Male","Female"],[0,1])

# %%
df.head(20)
# Out:
#       Gender     Height      Weight
# 4175       0  67.133444  175.152373
# 5396       1  64.328491  135.819094
# 1572       0  69.117657  197.491802
# 6766       1  68.186814  159.033590
# 5843       1  67.711232  145.408446
# 1287       0  69.518436  189.617454
# 4011       0  69.118045  203.596695
# 6856       1  68.440567  153.584231
# 4749       0  68.262739  183.078953
# 1383       0  68.127577  175.636538
# 2064       0  66.877783  186.880960
# 2069       0  68.085921  187.310482
# 6050       1  59.497406  125.601269
# 2893       0  69.605883  187.531900
# 218        0  71.774841  212.626102
# 7271       1  64.428289  138.225737
# 1086       0  71.507242  202.518458
# 5088       1  67.387451  164.892658
# 7847       1  60.623635  136.656055
# 3135       0  65.010905  157.611470

# %%
x = df[["Height"]]
y = df[["Gender"]]

# %%
y
# Out:
#       Gender
# 4175       0
# 5396       1
# 1572       0
# 6766       1
# 5843       1
# ...      ...
# 3971       0
# 3104       0
# 447        0
# 1113       0
# 1019       0
#
# [100 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.score(x,y)
# Out:
# 0.3984738550355462

# %%
lr.predict(x)
# Out:
# array([[ 0.45940504],
#        [ 0.69658086],
#        [ 0.29162778],
#        [ 0.37033626],
#        [ 0.41054962],
#        [ 0.25773949],
#        [ 0.29159498],
#        [ 0.3488799 ],
#        [ 0.36391628],
#        [ 0.37534509],
#        [ 0.48102273],
#        [ 0.37886737],
#        [ 1.10507845],
#        [ 0.25034537],
#        [ 0.06694674],
#        [ 0.68814237],
#        [ 0.08957385],
#        [ 0.43792722],
#        [ 1.00984894],
#        [ 0.63887867],
#        [ 1.03849939],
#        [ 0.69905613],
#        [ 0.79580271],
#        [ 0.36940768],
#        [ 0.28923893],
#        [ 0.2200718 ],
#        [ 0.16928494],
#        [ 0.38093337],
#        [ 0.59508271],
#        [-0.06027663],
#        [ 0.21785759],
#        [ 0.67444455],
#        [ 0.58961136],
#        [ 0.67573065],
#        [ 0.54232127],
#        [ 0.50585206],
#        [ 0.05775895],
#        [ 0.23991194],
#        [ 0.20992431],
#        [ 0.59544455],
#        [ 0.1699392 ],
# ...

# %%
plt.scatter(x,y)
plt.plot(x, lr.predict(x))

# %%
from sklearn.linear_model import LogisticRegression
loc = LogisticRegression()

# %%
loc.fit(x,y)
# Out:
# c:\Users\Sajib Saha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
loc.score(x,y)
# Out:
# 0.82

# %%
pred = loc.predict(x)

# %%
loc.predict_proba(x)
# Out:
# array([[0.54520762, 0.45479238],
#        [0.21241677, 0.78758323],
#        [0.77496816, 0.22503184],
#        [0.67733121, 0.32266879],
#        [0.61977833, 0.38022167],
#        [0.80995599, 0.19004401],
#        [0.77500413, 0.22499587],
#        [0.70609355, 0.29390645],
#        [0.6860923 , 0.3139077 ],
#        [0.67040787, 0.32959213],
#        [0.51133775, 0.48866225],
#        [0.66549439, 0.33450561],
#        [0.02023872, 0.97976128],
#        [0.81701159, 0.18298841],
#        [0.93399479, 0.06600521],
#        [0.22143145, 0.77856855],
#        [0.92466045, 0.07533955],
#        [0.5784498 , 0.4215502 ],
#        [0.03623736, 0.96376264],
#        [0.27938902, 0.72061098],
#        [0.03044384, 0.96955616],
#        [0.20982388, 0.79017612],
#        [0.12625487, 0.87374513],
#        [0.67860632, 0.32139368],
#        [0.77757756, 0.22242244],
#        [0.84378171, 0.15621829],
#        [0.88143285, 0.11856715],
#        [0.66259551, 0.33740449],
# ...

# %%
plt.scatter(x, y, color='blue', alpha=0.5, label='Data')
plt.plot(x , loc.predict_proba(x))

# %%
import numpy as np
x_range = np.linspace(x.min(), x.max(), 500).reshape(-1,1)
y_pre = loc.predict_proba(x_range)[:,1]
# Out:
# c:\Users\Sajib Saha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x,y, color = "green", alpha=.6, label = "main Data")
plt.plot(x_range, y_pre, color= "b", linewidth = 2, label = "loc curve")

# %%
from sklearn.metrics import confusion_matrix,precision_score, recall_score
cm = confusion_matrix(y, pred)

# %%
cm
# Out:
# array([[48,  7],
#        [11, 34]], dtype=int64)

# %%
sns.heatmap(cm, annot=True, cmap="rainbow")
# Out:
# <Axes: >

# %%
y.value_counts()
# Out:
# Gender
# 0         55
# 1         45
# Name: count, dtype: int64

# %%
precision_score(y, pred)
# Out:
# 0.8292682926829268

# %%
recall_score(y, pred)
# Out:
# 0.7555555555555555
